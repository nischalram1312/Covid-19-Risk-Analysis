# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mock_covid = pd.read_csv("Mock Covid.csv")

# %%
mock_covid.head()
# Out:
#    Patient No  Age  Gender  Height(cm)  Weight(kg)    BMI  Asthama  \
# 0           1    5       0         128          24  14.65        0
# 1           2   10       0         134          24  13.37        0
# 2           3    5       0         117          29  21.18        0
# 3           4    5       0         133          22  12.44        0
# 4           5    9       0         137          32  17.05        0
#
#    Blood Preassure  Blood Sugar  Strain  Smoking  Drinking    Risk  \
# 0                0            0       4        0         0   89.60
# 1                0            0       1        0         0   87.48
# 2                0            0       1        0         0  103.72
# 3                0            0       2        0         0   72.76
# 4                0            0       1        0         0   99.20
#
#    Medication  Recovered  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18
# 0           1          1          NaN          NaN          NaN          NaN
# ...

# %%
mock_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2405 entries, 0 to 2404
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Patient No       2405 non-null   int64
#  1   Age              2405 non-null   int64
#  2   Gender           2405 non-null   int64
#  3   Height(cm)       2405 non-null   int64
#  4   Weight(kg)       2405 non-null   int64
#  5   BMI              2405 non-null   float64
#  6   Asthama          2405 non-null   int64
#  7   Blood Preassure  2405 non-null   int64
#  8   Blood Sugar      2405 non-null   int64
#  9   Strain           2405 non-null   int64
#  10  Smoking          2405 non-null   int64
#  11  Drinking         2405 non-null   int64
#  12  Risk             2405 non-null   float64
#  13  Medication       2405 non-null   int64
#  14  Recovered        2405 non-null   int64
#  15  Unnamed: 15      0 non-null      float64
#  16  Unnamed: 16      0 non-null      float64
# ...

# %%
mock_covid = mock_covid.drop(['Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18'], axis=1)

# %%
mock_covid.describe()
# Out:
#         Patient No          Age       Gender   Height(cm)   Weight(kg)  \
# count  2405.000000  2405.000000  2405.000000  2405.000000  2405.000000
# mean   1203.000000    31.791684     0.501040   150.814553    55.737630
# std     694.408021    24.503545     0.500103    17.908894    21.911099
# min       1.000000     5.000000     0.000000   110.000000    18.000000
# 25%     602.000000    11.000000     0.000000   140.000000    33.000000
# 50%    1203.000000    19.000000     1.000000   155.000000    60.000000
# 75%    1804.000000    56.000000     1.000000   164.000000    75.000000
# max    2405.000000    80.000000     1.000000   178.000000    91.000000
#
#                BMI      Asthama  Blood Preassure  Blood Sugar       Strain  \
# count  2405.000000  2405.000000      2405.000000  2405.000000  2405.000000
# mean     23.446391     0.290229         0.299792     0.313929     3.520166
# std       6.074104     0.453962         0.635490     0.652648     1.714705
# ...

# %%
sns.pairplot(mock_covid)

# %%
sns.violinplot(mock_covid["Risk"])
# Out:
# D:\Users\adity\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Risk'>

# %%
sns.boxplot(mock_covid["Risk"])
# Out:
# D:\Users\adity\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Risk'>

# %%
sns.histplot(mock_covid["Risk"],kde=True)
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='Count'>

# %% [markdown]
# plt.pie(mock_covid['Recovered'])
# plt.show()

# %%
Figure = plt.figure(figsize=(15, 10))
sns.lineplot(x='Risk', y='BMI', data=mock_covid)
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='BMI'>

# %%
Figure = plt.figure(figsize=(15, 10))
sns.scatterplot(x='Risk', y='BMI', data=mock_covid)
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='BMI'>

# %%
Figure = plt.figure(figsize=(20, 15))
sns.barplot(x='Risk', y='BMI', data=mock_covid, palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='BMI'>

# %%
mock_covid['Strain']
# Out:
# 0       4
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 2400    5
# 2401    6
# 2402    3
# 2403    3
# 2404    2
# Name: Strain, Length: 2405, dtype: int64

# %%
sns.histplot(mock_covid["Strain"],kde=True)
# Out:
# <AxesSubplot:xlabel='Strain', ylabel='Count'>

# %%
Figure = plt.figure(figsize=(15, 10))
sns.lineplot(x='Blood Preassure', y='Risk', hue='Strain', data=mock_covid, ci=None, palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Blood Preassure', ylabel='Risk'>

# %%
Figure = plt.figure(figsize=(15, 10))
sns.scatterplot(x='Age', y='Risk', hue='Strain', data=mock_covid, ci=None, palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Risk'>

# %%
Figure = plt.figure(figsize=(15, 10))
sns.barplot(x='Smoking', y='Risk', hue='Strain', data=mock_covid, ci=None, palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Smoking', ylabel='Risk'>

# %%
sns.jointplot(x = 'Risk', y = 'BMI' , data = mock_covid, color='orange')

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.model_selection import train_test_split

# %%
X = mock_covid.drop('Recovered', axis=1)
Y = mock_covid['Recovered']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,Y_train)
# Out:
# D:\Users\adity\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print("\t\t\tEvaluation\n\nClassification Report\n")
print(classification_report(Y_test,Predictions))
print("\nConfusion Matrix\n")
print(confusion_matrix(Y_test,Predictions))
# Out:
# 			Evaluation
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        64
#            1       0.91      1.00      0.95       658
#
#     accuracy                           0.91       722
#    macro avg       0.46      0.50      0.48       722
# weighted avg       0.83      0.91      0.87       722
#
#
# Confusion Matrix
#
# [[  0  64]
#  [  0 658]]
